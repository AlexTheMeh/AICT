# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexTheMeh/AICT/blob/main/AICourseWorkNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import libraries
# %matplotlib inline

import skimage.transform
import numpy as np
import torch
import torch.nn as nn
import torch.nn. functional as F

from PIL import Image
import matplotlib.pyplot as imshow
from torchvision import datasets, transforms, models
from torchvision.utils import save_image
import matplotlib.pyplot as plt


#from utils.visualize import visualize, reverse_normalize
#from utils.imagenet_labels import label2idx, idx2label
import matplotlib.image as mpimg

# check if CUDA is available
train_on_gpu = torch.cuda.is_available()

if not train_on_gpu:
  print('CUDA is not available. Training on CPU.')
else:
  print('CUDA is available. Training on GPU.')
# Out:
# CUDA is available. Training on GPU.

# %%
# imshow function for displaying images
def imshow(image, ax=None, title=None, normalize=True):
    """Imshow for Tensor."""
    if ax is None:
        fig, ax = plt.subplots()
    image = image.numpy().transpose((1, 2, 0))

    if normalize:
        mean = np.array([0.485, 0.456, 0.406])
        std = np.array([0.229, 0.224, 0.225])
        image = std * image + mean
        image = np.clip(image, 0, 1)

    ax.imshow(image)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.tick_params(axis='both', length=0)
    ax.set_xticklabels('')
    ax.set_yticklabels('')

    return ax

# %%
# mount google drive
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
# unzip dataset folder 
# !unzip '/content/gdrive/MyDrive/SharkDataSetDis.zip' > /dev/null
# Out:
# replace SharkDataSetDis/Testing/BullSharks/Bull459.jpg? [y]es, [n]o, [A]ll, [N]one, [r]ename: A

# %%
# dataset directory
data_dir = 'SharkDataSetDis'

# define batch size
batch_size = 32

# define transforms
# training (with random flips and rotation)
train_transform = transforms.Compose([transforms.Resize(236), # resize to 236x?
                                transforms.RandomRotation(5), # random rotation
                                transforms.CenterCrop(224), # take a square (224x224) crop from the centre
                                transforms.RandomHorizontalFlip(), # randomly flip on horizontal axis
                                transforms.ToTensor(), # convert data to torch.FloatTensor
                                transforms.Normalize([0.485, 0.456, 0.406],
                                                     [0.229, 0.224, 0.225])]) # normalise for each colour channel
                              
# validation and testing
transform = transforms.Compose([transforms.Resize(224), # resize to 224x?
                                transforms.CenterCrop(224), # take a square (224x224) crop from the centre
                                transforms.ToTensor(), # convert data to torch.FloatTensor
                                transforms.Normalize([0.485, 0.456, 0.406],
                                                     [0.229, 0.224, 0.225])]) # normalise for each colour channel

# choose the training, validation and test datasets
train_data = datasets.ImageFolder(data_dir + '/Train', transform=train_transform)
val_data = datasets.ImageFolder(data_dir + '/Validation', transform=transform)
test_data = datasets.ImageFolder(data_dir + '/Testing', transform=transform)

# prepare the data loaders
train_loader = torch.utils.data.DataLoader(train_data, batch_size, shuffle=True)
val_loader = torch.utils.data.DataLoader(val_data, batch_size, shuffle=True)
test_loader = torch.utils.data.DataLoader(test_data, batch_size, shuffle=True)

# %%
# obtain one batch of training images
data_iter = iter(train_loader)
images, labels = next(data_iter)

# plot the first 4 images in the batch, along with the corresponding labels
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
    imshow(images[ii], ax=ax, normalize=True)
    ax.set_title(str(labels[ii].item()))

# %%
#########################################################################
# use a ResNet18 network
# #########################################################################
# NB This network requires an image input size of 3x224x224 and normalised using mean = [0.485, 0.456, 0.406] and std = [0.229, 0.224, 0.225].

import torch.nn as nn
import torchvision.models as models

# load a pre-trained ResNet network with 18 layers
model = models.resnet18(pretrained=True)

# # if we use the following code the pre-trained weights are frozen and we only update the final layer
# for param in model.parameters():
#     param.requires_grad = False

# get the number of inputs for the final layer (fc) of the network
num_ftrs = model.fc.in_features
# replace the final layer so that the output is number of classes
model.fc = nn.Linear(num_ftrs, 6)

# move tensors to GPU if CUDA is available
if train_on_gpu:
    model.cuda()

print(model)

# #########################################################################
# #########################################################################
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=6, bias=True)
# )

# %%
import torch.optim as optim

# specify loss function (cross entropy loss)
criterion = nn.CrossEntropyLoss()
# specify optimiser (Adam optimiser) and learning rate = 0.001
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# number of epochs to train the model
n_epochs = 200

# initialise tracker for minimum validation loss
valid_loss_min = np.Inf # set initial "min" to infinity

# create empty lists to store the training and validation losses
train_losses, val_losses = [], []

for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    
    ###################
    # train the model #
    ###################
    model.train() # prep model for training
    for data, target in train_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    ######################    
    # validate the model #
    ######################
    model.eval() # prep model for evaluation
    for data, target in val_loader:
        # move tensors to GPU if CUDA is available
        if train_on_gpu:
            data, target = data.cuda(), target.cuda()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # update running validation loss 
        valid_loss += loss.item()*data.size(0)
        
    # print training/validation statistics 
    # calculate average loss over an epoch
    train_loss = train_loss/len(train_loader.sampler)
    valid_loss = valid_loss/len(val_loader.sampler)

    # store the training and validation losses for later visualisation
    train_losses.append(train_loss)
    val_losses.append(valid_loss)
    
    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    
    # save model if validation loss has decreased
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(
        valid_loss_min,
        valid_loss))
        torch.save(model.state_dict(), 'resnet18_model_fine_tune_aug.pt') # save in colab
        torch.save(model.state_dict(), '/content/gdrive/MyDrive/resnet18_model_fine_tune_aug.pt') # save in google drive
        valid_loss_min = valid_loss
# Out:
# Epoch: 1 	Training Loss: 1.145055 	Validation Loss: 5.381765
# Validation loss decreased (inf --> 5.381765).  Saving model ...
# Epoch: 2 	Training Loss: 0.720636 	Validation Loss: 1.879127
# Validation loss decreased (5.381765 --> 1.879127).  Saving model ...
# Epoch: 3 	Training Loss: 0.480159 	Validation Loss: 0.758853
# Validation loss decreased (1.879127 --> 0.758853).  Saving model ...
# Epoch: 4 	Training Loss: 0.484429 	Validation Loss: 1.263377
# Epoch: 5 	Training Loss: 0.415314 	Validation Loss: 0.702349
# Validation loss decreased (0.758853 --> 0.702349).  Saving model ...
# Epoch: 6 	Training Loss: 0.373773 	Validation Loss: 0.857798
# Epoch: 7 	Training Loss: 0.347019 	Validation Loss: 1.083036
# Epoch: 8 	Training Loss: 0.302920 	Validation Loss: 0.986210
# Epoch: 9 	Training Loss: 0.289597 	Validation Loss: 0.789817
# Epoch: 10 	Training Loss: 0.253744 	Validation Loss: 1.200132
# Epoch: 11 	Training Loss: 0.201774 	Validation Loss: 1.478693
# Epoch: 12 	Training Loss: 0.209989 	Validation Loss: 0.826894
# Epoch: 13 	Training Loss: 0.224647 	Validation Loss: 1.242831
# Epoch: 14 	Training Loss: 0.265047 	Validation Loss: 1.280779
# Epoch: 15 	Training Loss: 0.326191 	Validation Loss: 1.068530
# Epoch: 16 	Training Loss: 0.224441 	Validation Loss: 1.175366
# Epoch: 17 	Training Loss: 0.167368 	Validation Loss: 1.155758
# Epoch: 18 	Training Loss: 0.162747 	Validation Loss: 0.915592
# Epoch: 19 	Training Loss: 0.281535 	Validation Loss: 1.126229
# Epoch: 20 	Training Loss: 0.189419 	Validation Loss: 0.959031
# Epoch: 21 	Training Loss: 0.163585 	Validation Loss: 0.894128
# Epoch: 22 	Training Loss: 0.131292 	Validation Loss: 1.028601
# Epoch: 23 	Training Loss: 0.087790 	Validation Loss: 1.091059
# Epoch: 24 	Training Loss: 0.083945 	Validation Loss: 1.184092
# Epoch: 25 	Training Loss: 0.142701 	Validation Loss: 1.087647
# Epoch: 26 	Training Loss: 0.088267 	Validation Loss: 0.938265
# Epoch: 27 	Training Loss: 0.085647 	Validation Loss: 1.255178
# Epoch: 28 	Training Loss: 0.104795 	Validation Loss: 0.980038
# Epoch: 29 	Training Loss: 0.062382 	Validation Loss: 0.898661
# Epoch: 30 	Training Loss: 0.116771 	Validation Loss: 1.208614
# Epoch: 31 	Training Loss: 0.085962 	Validation Loss: 1.453580
# Epoch: 32 	Training Loss: 0.051925 	Validation Loss: 1.084478
# Epoch: 33 	Training Loss: 0.039840 	Validation Loss: 1.074310
# Epoch: 34 	Training Loss: 0.086831 	Validation Loss: 1.075839
# Epoch: 35 	Training Loss: 0.146196 	Validation Loss: 1.514188
# Epoch: 36 	Training Loss: 0.127281 	Validation Loss: 0.866856
# Epoch: 37 	Training Loss: 0.145589 	Validation Loss: 1.201314
# Epoch: 38 	Training Loss: 0.138267 	Validation Loss: 0.988026
# Epoch: 39 	Training Loss: 0.134006 	Validation Loss: 1.210934
# Epoch: 40 	Training Loss: 0.118479 	Validation Loss: 1.351504
# Epoch: 41 	Training Loss: 0.155867 	Validation Loss: 1.467608
# Epoch: 42 	Training Loss: 0.104388 	Validation Loss: 1.283894
# Epoch: 43 	Training Loss: 0.068854 	Validation Loss: 1.028225
# Epoch: 44 	Training Loss: 0.067375 	Validation Loss: 1.242983
# Epoch: 45 	Training Loss: 0.069463 	Validation Loss: 1.168873
# Epoch: 46 	Training Loss: 0.171980 	Validation Loss: 1.533088
# Epoch: 47 	Training Loss: 0.260426 	Validation Loss: 2.043206
# Epoch: 48 	Training Loss: 0.227513 	Validation Loss: 1.347302
# Epoch: 49 	Training Loss: 0.170205 	Validation Loss: 1.283445
# Epoch: 50 	Training Loss: 0.086113 	Validation Loss: 1.125542
# Epoch: 51 	Training Loss: 0.041129 	Validation Loss: 1.057792
# Epoch: 52 	Training Loss: 0.057307 	Validation Loss: 1.280113
# Epoch: 53 	Training Loss: 0.034689 	Validation Loss: 1.365197
# Epoch: 54 	Training Loss: 0.042433 	Validation Loss: 1.497593
# Epoch: 55 	Training Loss: 0.072145 	Validation Loss: 1.451961
# Epoch: 56 	Training Loss: 0.064244 	Validation Loss: 1.417925
# Epoch: 57 	Training Loss: 0.041140 	Validation Loss: 1.311321
# Epoch: 58 	Training Loss: 0.053303 	Validation Loss: 1.513705
# Epoch: 59 	Training Loss: 0.078430 	Validation Loss: 1.453149
# Epoch: 60 	Training Loss: 0.112062 	Validation Loss: 1.449817
# Epoch: 61 	Training Loss: 0.174686 	Validation Loss: 2.122637
# Epoch: 62 	Training Loss: 0.175689 	Validation Loss: 1.446777
# Epoch: 63 	Training Loss: 0.089392 	Validation Loss: 1.057472
# Epoch: 64 	Training Loss: 0.052394 	Validation Loss: 1.116114
# Epoch: 65 	Training Loss: 0.038237 	Validation Loss: 1.094406
# Epoch: 66 	Training Loss: 0.038337 	Validation Loss: 1.156214
# Epoch: 67 	Training Loss: 0.038478 	Validation Loss: 1.016780
# Epoch: 68 	Training Loss: 0.024212 	Validation Loss: 1.007936
# Epoch: 69 	Training Loss: 0.021538 	Validation Loss: 1.034552
# Epoch: 70 	Training Loss: 0.024908 	Validation Loss: 1.089582
# Epoch: 71 	Training Loss: 0.139296 	Validation Loss: 1.660791
# Epoch: 72 	Training Loss: 0.117420 	Validation Loss: 1.454262
# Epoch: 73 	Training Loss: 0.103460 	Validation Loss: 1.240031
# Epoch: 74 	Training Loss: 0.074253 	Validation Loss: 1.289883
# Epoch: 75 	Training Loss: 0.068402 	Validation Loss: 1.210485
# Epoch: 76 	Training Loss: 0.031672 	Validation Loss: 1.131500
# Epoch: 77 	Training Loss: 0.027729 	Validation Loss: 1.080927
# Epoch: 78 	Training Loss: 0.034570 	Validation Loss: 1.194922
# Epoch: 79 	Training Loss: 0.030321 	Validation Loss: 1.292326
# Epoch: 80 	Training Loss: 0.028936 	Validation Loss: 1.310605
# Epoch: 81 	Training Loss: 0.094112 	Validation Loss: 1.899056
# Epoch: 82 	Training Loss: 0.074230 	Validation Loss: 1.351011
# Epoch: 83 	Training Loss: 0.059162 	Validation Loss: 1.476605
# Epoch: 84 	Training Loss: 0.126242 	Validation Loss: 1.310759
# Epoch: 85 	Training Loss: 0.103926 	Validation Loss: 1.272624
# Epoch: 86 	Training Loss: 0.232564 	Validation Loss: 1.803466
# Epoch: 87 	Training Loss: 0.134737 	Validation Loss: 1.711087
# Epoch: 88 	Training Loss: 0.075663 	Validation Loss: 1.081965
# Epoch: 89 	Training Loss: 0.080271 	Validation Loss: 1.346320
# Epoch: 90 	Training Loss: 0.068904 	Validation Loss: 1.176436
# Epoch: 91 	Training Loss: 0.051491 	Validation Loss: 1.342295
# Epoch: 92 	Training Loss: 0.034255 	Validation Loss: 1.253602
# Epoch: 93 	Training Loss: 0.046991 	Validation Loss: 1.459730
# Epoch: 94 	Training Loss: 0.031699 	Validation Loss: 1.325202
# Epoch: 95 	Training Loss: 0.047847 	Validation Loss: 1.507493
# Epoch: 96 	Training Loss: 0.036012 	Validation Loss: 1.247096
# Epoch: 97 	Training Loss: 0.030854 	Validation Loss: 1.193000
# Epoch: 98 	Training Loss: 0.053823 	Validation Loss: 1.206863
# Epoch: 99 	Training Loss: 0.098253 	Validation Loss: 1.288733
# Epoch: 100 	Training Loss: 0.125276 	Validation Loss: 1.914808
# Epoch: 101 	Training Loss: 0.105006 	Validation Loss: 1.329560
# Epoch: 102 	Training Loss: 0.070774 	Validation Loss: 1.253262
# Epoch: 103 	Training Loss: 0.038677 	Validation Loss: 1.299713
# Epoch: 104 	Training Loss: 0.037885 	Validation Loss: 1.290578
# Epoch: 105 	Training Loss: 0.023945 	Validation Loss: 1.370953
# Epoch: 106 	Training Loss: 0.019422 	Validation Loss: 1.439611
# Epoch: 107 	Training Loss: 0.021595 	Validation Loss: 1.392839
# Epoch: 108 	Training Loss: 0.018317 	Validation Loss: 1.542515
# Epoch: 109 	Training Loss: 0.018341 	Validation Loss: 1.491325
# Epoch: 110 	Training Loss: 0.018776 	Validation Loss: 1.518140
# Epoch: 111 	Training Loss: 0.016132 	Validation Loss: 1.462209
# Epoch: 112 	Training Loss: 0.042167 	Validation Loss: 1.725720
# Epoch: 113 	Training Loss: 0.050992 	Validation Loss: 1.960515
# Epoch: 114 	Training Loss: 0.058323 	Validation Loss: 1.725614
# Epoch: 115 	Training Loss: 0.045703 	Validation Loss: 1.791951
# Epoch: 116 	Training Loss: 0.026454 	Validation Loss: 1.875233
# Epoch: 117 	Training Loss: 0.020476 	Validation Loss: 1.923556
# Epoch: 118 	Training Loss: 0.020540 	Validation Loss: 1.917358
# Epoch: 119 	Training Loss: 0.018980 	Validation Loss: 1.801553
# Epoch: 120 	Training Loss: 0.016945 	Validation Loss: 1.743066
# Epoch: 121 	Training Loss: 0.017079 	Validation Loss: 1.696305
# Epoch: 122 	Training Loss: 0.015826 	Validation Loss: 1.720579
# Epoch: 123 	Training Loss: 0.017395 	Validation Loss: 1.704261
# Epoch: 124 	Training Loss: 0.015566 	Validation Loss: 1.680951
# Epoch: 125 	Training Loss: 0.016165 	Validation Loss: 1.732720
# Epoch: 126 	Training Loss: 0.013347 	Validation Loss: 1.742062
# Epoch: 127 	Training Loss: 0.016219 	Validation Loss: 1.734109
# Epoch: 128 	Training Loss: 0.018376 	Validation Loss: 1.712103
# Epoch: 129 	Training Loss: 0.015034 	Validation Loss: 1.694696
# Epoch: 130 	Training Loss: 0.014988 	Validation Loss: 1.700977
# Epoch: 131 	Training Loss: 0.013934 	Validation Loss: 1.683276
# Epoch: 132 	Training Loss: 0.015519 	Validation Loss: 1.668294
# Epoch: 133 	Training Loss: 0.013926 	Validation Loss: 1.664414
# Epoch: 134 	Training Loss: 0.015601 	Validation Loss: 1.677722
# Epoch: 135 	Training Loss: 0.014907 	Validation Loss: 1.709510
# Epoch: 136 	Training Loss: 0.014069 	Validation Loss: 1.724229
# Epoch: 137 	Training Loss: 0.012717 	Validation Loss: 1.706427
# Epoch: 138 	Training Loss: 0.014196 	Validation Loss: 1.721491
# Epoch: 139 	Training Loss: 0.016170 	Validation Loss: 1.702852
# Epoch: 140 	Training Loss: 0.018171 	Validation Loss: 1.628778
# Epoch: 141 	Training Loss: 0.013252 	Validation Loss: 1.586300
# Epoch: 142 	Training Loss: 0.016518 	Validation Loss: 1.661429
# Epoch: 143 	Training Loss: 0.014845 	Validation Loss: 1.656097
# Epoch: 144 	Training Loss: 0.012571 	Validation Loss: 1.657423
# Epoch: 145 	Training Loss: 0.018076 	Validation Loss: 1.817869
# Epoch: 146 	Training Loss: 0.099999 	Validation Loss: 2.043452
# Epoch: 147 	Training Loss: 0.236412 	Validation Loss: 2.449970
# Epoch: 148 	Training Loss: 0.225946 	Validation Loss: 1.378537
# Epoch: 149 	Training Loss: 0.131723 	Validation Loss: 1.336507
# Epoch: 150 	Training Loss: 0.100602 	Validation Loss: 1.239930
# Epoch: 151 	Training Loss: 0.080462 	Validation Loss: 1.691437
# Epoch: 152 	Training Loss: 0.086774 	Validation Loss: 1.610944
# Epoch: 153 	Training Loss: 0.139795 	Validation Loss: 1.557751
# Epoch: 154 	Training Loss: 0.054797 	Validation Loss: 1.197501
# Epoch: 155 	Training Loss: 0.025919 	Validation Loss: 1.354810
# Epoch: 156 	Training Loss: 0.028096 	Validation Loss: 1.356616
# Epoch: 157 	Training Loss: 0.024006 	Validation Loss: 1.439635
# Epoch: 158 	Training Loss: 0.027716 	Validation Loss: 1.393863
# Epoch: 159 	Training Loss: 0.021081 	Validation Loss: 1.376284
# Epoch: 160 	Training Loss: 0.015349 	Validation Loss: 1.378632
# Epoch: 161 	Training Loss: 0.014684 	Validation Loss: 1.450525
# Epoch: 162 	Training Loss: 0.016131 	Validation Loss: 1.411692
# Epoch: 163 	Training Loss: 0.015920 	Validation Loss: 1.484342
# Epoch: 164 	Training Loss: 0.013815 	Validation Loss: 1.496586
# Epoch: 165 	Training Loss: 0.015057 	Validation Loss: 1.507709
# Epoch: 166 	Training Loss: 0.023583 	Validation Loss: 1.542666
# Epoch: 167 	Training Loss: 0.016724 	Validation Loss: 1.512362
# Epoch: 168 	Training Loss: 0.018186 	Validation Loss: 1.490832
# Epoch: 169 	Training Loss: 0.018480 	Validation Loss: 1.497887
# Epoch: 170 	Training Loss: 0.016220 	Validation Loss: 1.466815
# Epoch: 171 	Training Loss: 0.021408 	Validation Loss: 1.508900
# Epoch: 172 	Training Loss: 0.039101 	Validation Loss: 1.561074
# Epoch: 173 	Training Loss: 0.067027 	Validation Loss: 1.829592
# Epoch: 174 	Training Loss: 0.065631 	Validation Loss: 1.638340
# Epoch: 175 	Training Loss: 0.038748 	Validation Loss: 1.754226
# Epoch: 176 	Training Loss: 0.034586 	Validation Loss: 1.663193
# Epoch: 177 	Training Loss: 0.035988 	Validation Loss: 1.821470
# Epoch: 178 	Training Loss: 0.037216 	Validation Loss: 2.567785
# Epoch: 179 	Training Loss: 0.051041 	Validation Loss: 1.731445
# Epoch: 180 	Training Loss: 0.039387 	Validation Loss: 1.865037
# Epoch: 181 	Training Loss: 0.405478 	Validation Loss: 4.227237
# Epoch: 182 	Training Loss: 0.462447 	Validation Loss: 1.909096
# Epoch: 183 	Training Loss: 0.220617 	Validation Loss: 1.429993
# Epoch: 184 	Training Loss: 0.114073 	Validation Loss: 1.337057
# Epoch: 185 	Training Loss: 0.058450 	Validation Loss: 1.196189
# Epoch: 186 	Training Loss: 0.053548 	Validation Loss: 1.250434
# Epoch: 187 	Training Loss: 0.043037 	Validation Loss: 1.198967
# Epoch: 188 	Training Loss: 0.038155 	Validation Loss: 1.230509
# Epoch: 189 	Training Loss: 0.038243 	Validation Loss: 1.168563
# Epoch: 190 	Training Loss: 0.026342 	Validation Loss: 1.185900
# Epoch: 191 	Training Loss: 0.020062 	Validation Loss: 1.266668
# Epoch: 192 	Training Loss: 0.018358 	Validation Loss: 1.352404
# Epoch: 193 	Training Loss: 0.022057 	Validation Loss: 1.382434
# Epoch: 194 	Training Loss: 0.022750 	Validation Loss: 1.415081
# Epoch: 195 	Training Loss: 0.015039 	Validation Loss: 1.367272
# Epoch: 196 	Training Loss: 0.030185 	Validation Loss: 1.474916
# Epoch: 197 	Training Loss: 0.018654 	Validation Loss: 1.388947
# Epoch: 198 	Training Loss: 0.019691 	Validation Loss: 1.366578
# Epoch: 199 	Training Loss: 0.012838 	Validation Loss: 1.367651
# Epoch: 200 	Training Loss: 0.024232 	Validation Loss: 1.544670

# %%
# visualise the training and validation losses over time
plt.plot(train_losses, label='Training loss')
plt.plot(val_losses, label='Validation loss')
plt.legend(frameon=False)

# %%
# Load the Model with the Lowest Validation Loss
model.load_state_dict(torch.load('resnet18_model_fine_tune_aug.pt'))
# Out:
# <All keys matched successfully>

# %%
# Test the Trained Network

# initialize lists to monitor test loss and accuracy
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for evaluation

for data, target in test_loader:
    # move tensors to GPU if CUDA is available
    if train_on_gpu:
        data, target = data.cuda(), target.cuda()
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(len(target)):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.sampler)
print('Test Loss: {:.6f}\n'.format(test_loss))

# change value here to number of classes
for i in range(3):
    if class_total[i] > 0:
        print('Test Accuracy of %5s: %2d%% (%2d/%2d)' % (
            str(i), 100 * class_correct[i] / class_total[i],
            np.sum(class_correct[i]), np.sum(class_total[i])))
    else:
        print('Test Accuracy of %5s: N/A (no training examples)' % (classes[i]))

print('\nTest Accuracy (Overall): %2d%% (%2d/%2d)' % (
    100. * np.sum(class_correct) / np.sum(class_total),
    np.sum(class_correct), np.sum(class_total)))
# Out:
# Test Loss: 0.870791
#
# Test Accuracy of     0: 48% (17/35)
# Test Accuracy of     1: 63% (23/36)
# Test Accuracy of     2: 79% (34/43)
#
# Test Accuracy (Overall): 64% (74/114)

# %%
# Visualize Sample Test Results

# obtain one batch of test images
dataiter = iter(test_loader)
images, labels = dataiter.next()
images.numpy()

# move model inputs to cuda, if GPU available
if train_on_gpu:
    images = images.cuda()

# get sample outputs
output = model(images)
# convert output probabilities to predicted class
_, preds_tensor = torch.max(output, 1)
preds = np.squeeze(preds_tensor.numpy()) if not train_on_gpu else np.squeeze(preds_tensor.cpu().numpy())

# plot the first 4 images in the batch, along with the corresponding labels
fig, axes = plt.subplots(figsize=(10,4), ncols=4)
for ii in range(4):
    ax = axes[ii]
    imshow(images.cpu()[ii], ax=ax, normalize=True)
    ax.set_title("{} ({})".format(str(preds[ii].item()), str(labels[ii].item())),
                 color=("green" if preds[ii]==labels[ii] else "red"))
